# %%
import pandas as pd
import matplotlib as mt
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('data/housing.csv')

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.sort_values(by='Area Population')
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 314        68929.15807             7.590878                   6.891969
# 1530       85175.20063             7.750852                   7.271163
# 2756       62173.58010             5.098959                   5.662268
# 2534       79442.50580             6.300600                   5.983205
# 4491       66513.88445             6.778404                   8.044497
# ...                ...                  ...                        ...
# 3991       50041.12522             5.981267                   8.699555
# 353        72445.03330             5.488197                   6.509449
# 228        66574.70999             5.550265                   6.844150
# 1595       64350.28457             6.761203                   7.128710
# 4803       61846.13590             5.057578                   7.681141
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df['Avg. Area Income'].median()
# Out:
# 68804.28640499999

# %%
df['Price'].median()
# Out:
# 1232669.378

# %%
df.hist(bins=20, figsize=(20,15))
plt.suptitle("Histogram of each feature")
plt.show()

# %%
df.plot(kind='scatter', x='Avg. Area Income', y='Price', alpha=0.4)
plt.title('Price vs. Avg. Area Income')
plt.show()

# %%
df.plot(kind='scatter', x='Avg. Area House Age', y='Price', alpha=0.4)
plt.title('Price vs. Avg. Area House Age')
plt.show()

# %%
df.plot(kind='scatter', x='Area Population', y='Price', alpha=0.4)
plt.title('Price vs. Area Population')
plt.show()
